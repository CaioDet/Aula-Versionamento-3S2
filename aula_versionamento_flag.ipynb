# %% [markdown]
# <a href="https://colab.research.google.com/github/CaioDet/Aula-Versionamento-3S2/blob/main/aula_versionamento_flag.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Chave de Controle (Feature Flag)
flag_entrada_celular = False  # False = Desativado | True = Ativado

# 2. Sistema de Validação da Catraca
def rodar_catraca():
    print(" CATRACA ESCOLAR ATIVA ")
    print("Mecanismo padrão: Aproxime sua CARTEIRINHA")

    # Aqui entra a nossa nova funcionalidade oculta
    if flag_entrada_celular == False:
        print("[ATUALIZAÇÃO ATIVA]: aproxime o celular")

# 3. Executando o leitor da catraca
rodar_catraca()
# Out:
#  CATRACA ESCOLAR ATIVA
# Mecanismo padrão: Aproxime sua CARTEIRINHA
# [ATUALIZAÇÃO ATIVA]: aproxime o celular

# %%
def rodar_catraca():
<<<<<<< HEAD
    # Código feito pelo Programador A (Branch: feature-foto-perfil)
    print("=== SISTEMA NOVO DE CATRACA DA ESCOLA ===")
    print("Identificação: Use a CARTEIRINHA ou RECONHECIMENTO FACIAL. 👤")
    print("[FOTO]: Buscando foto do aluno no banco de dados...")
=======
    # Código feito pelo Programador B (Branch: feature-entrada-celular)
    print("=== CATRACA ESCOLAR ATIVA ===")
    print("Mecanismo: Aproxime o seu CELULAR (NFC) no leitor. 📱")
    print("[MENSAGEM]: Liberado via smartphone.")
>>>>>>> feature-entrada-celular

rodar_catraca()
